# %%
from flask import Flask, request,render_template,jsonify
import flasgger
from flasgger import Swagger

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# absl-py                           1.3.0
# aiofiles                          23.1.0
# aiohttp                           3.8.3
# aiosignal                         1.3.1
# ansi2html                         1.8.0
# ansiwrap                          0.8.4
# anyio                             3.4.0
# argon2-cffi                       21.1.0
# asgiref                           3.6.0
# astunparse                        1.6.3
# async-timeout                     4.0.2
# attrs                             21.2.0
# Babel                             2.9.1
# backcall                          0.2.0
# basemap                           1.2.1
# beautifulsoup4                    4.11.2
# bidict                            0.22.1
# bleach                            4.1.0
# blinker                           1.5
# Brotli                            1.0.9
# cached-property                   1.5.2
# cachelib                          0.9.0
# cachetools                        4.2.4
# cairocffi                         1.4.0
# certifi                           2019.11.28
# cffi                              1.15.0
# channels                          4.0.0
# chardet                           3.0.4
# charset-normalizer                2.1.1
# click                             8.0.3
# cx-Oracle                         8.3.0
# cycler                            0.11.0
# dash                              2.8.1
# dash-bootstrap-components         1.3.1
# dash-core-components              2.0.0
# dash-extensions                   0.1.12
# dash-html-components              2.0.0
# dash-leaflet                      0.1.23
# dash-table                        5.0.0
# datefinder                        0.7.3
# dbus-python                       1.2.16
# debugpy                           1.5.1
# decorator                         5.1.0
# defusedxml                        0.7.1
# Django                            3.2.17
# django-bootstrap4                 22.3
# django-plotly-dash                2.1.3
# dpd-components                    0.1.0
# dpd-static-support                0.0.5
# EditorConfig                      0.12.3
# efficientnet                      1.0.0
# elasticsearch                     7.15.2
# entrypoints                       0.3
# et-xmlfile                        1.1.0
# filelock                          3.9.0
# flasgger                          0.9.5
# Flask                             2.0.1
# Flask-Caching                     2.0.2
# Flask-Compress                    1.10.1
# Flask-SocketIO                    5.3.2
# flatbuffers                       2.0
# frozenlist                        1.3.3
# fuzzywuzzy                        0.18.0
# gast                              0.4.0
# geobuf                            1.1.1
# geographiclib                     1.52
# geopy                             2.2.0
# google-auth                       2.3.3
# google-auth-oauthlib              0.4.6
# google-pasta                      0.2.0
# GPUtil                            1.4.0
# graphviz                          0.19
# greenlet                          2.0.1
# grpcio                            1.41.1
# h11                               0.14.0
# h2                                4.1.0
# h5py                              3.5.0
# hpack                             4.0.0
# huggingface-hub                   0.11.1
# hypercorn                         0.14.3
# hyperframe                        6.0.1
# idna                              2.8
# igraph                            0.9.8
# image-classifiers                 1.0.0
# imageio                           2.24.0
# importlib-metadata                6.0.0
# importlib-resources               5.4.0
# install                           1.3.5
# ipykernel                         5.1.1
# ipyleaflet                        0.14.0
# ipyparallel                       8.0.0
# ipython                           7.29.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.5
# isodate                           0.6.0
# itsdangerous                      2.0.1
# jedi                              0.17.2
# Jinja2                            3.0.2
# joblib                            1.1.0
# jsbeautifier                      1.14.7
# json2html                         1.3.0
# json5                             0.9.6
# jsonschema                        4.2.0
# jupyter                           1.0.0
# jupyter-client                    7.0.6
# jupyter-console                   6.4.0
# jupyter-contrib-core              0.4.2
# jupyter-contrib-nbextensions      0.7.0
# jupyter-core                      4.9.1
# jupyter-dash                      0.4.2
# jupyter-highlight-selected-word   0.2.0
# jupyter-http-over-ws              0.0.8
# jupyter-nbextensions-configurator 0.6.1
# jupyter-plotly-dash               0.4.3
# jupyter-server                    1.12.1
# jupyterlab                        3.2.4
# jupyterlab-pygments               0.1.2
# jupyterlab-server                 2.8.2
# jupyterlab-widgets                1.0.2
# keras                             2.11.0
# Keras-Applications                1.0.8
# Keras-Preprocessing               1.1.2
# kiwisolver                        1.3.2
# Levenshtein                       0.20.9
# libclang                          15.0.6.1
# llvmlite                          0.39.1
# lxml                              4.6.4
# Markdown                          3.3.4
# MarkupSafe                        2.1.2
# matplotlib                        3.4.3
# matplotlib-inline                 0.1.3
# mistune                           0.8.4
# more-itertools                    9.0.0
# mpmath                            1.2.1
# multidict                         6.0.4
# nbclassic                         0.3.4
# nbclient                          0.5.4
# nbconvert                         6.2.0
# nbformat                          5.1.3
# nbserverproxy                     0.8.8
# nest-asyncio                      1.5.1
# networkx                          3.0
# nltk                              3.6.5
# notebook                          6.4.5
# numba                             0.56.4
# numpy                             1.21.3
# nvidia-cublas-cu11                11.10.3.66
# nvidia-cuda-nvrtc-cu11            11.7.99
# nvidia-cuda-runtime-cu11          11.7.99
# nvidia-cudnn-cu11                 8.5.0.96
# oauthlib                          3.1.1
# olefile                           0.46
# opencv-python                     4.7.0.68
# openpyxl                          3.0.10
# opt-einsum                        3.3.0
# packaging                         21.2
# pandas                            1.5.2
# pandocfilters                     1.5.0
# papermill                         2.4.0
# parso                             0.7.1
# pexpect                           4.8.0
# pickleshare                       0.7.5
# Pillow                            8.4.0
# pip                               23.0.1
# platformdirs                      2.4.0
# plotly                            5.4.0
# priority                          2.0.0
# prometheus-client                 0.12.0
# prompt-toolkit                    3.0.22
# protobuf                          3.19.1
# psutil                            5.8.0
# ptyprocess                        0.7.0
# pyarrow                           10.0.1
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pybind11                          2.10.3
# pycparser                         2.20
# pydot                             1.4.2
# Pygments                          2.10.0
# PyGObject                         3.36.0
# pynndescent                       0.5.8
# pyparsing                         2.4.7
# pyproj                            2.5.0
# pyrsistent                        0.18.0
# pyshp                             2.1.0
# python-apt                        2.0.0+ubuntu0.20.4.6
# python-dateutil                   2.8.2
# python-engineio                   4.3.4
# python-igraph                     0.9.8
# python-Levenshtein                0.20.9
# python-socketio                   5.7.2
# pytz                              2021.3
# PyWavelets                        1.4.1
# PyYAML                            6.0
# pyzmq                             22.3.0
# qtconsole                         5.1.1
# QtPy                              1.11.2
# quart                             0.18.3
# rapidfuzz                         2.13.7
# regex                             2021.11.10
# requests                          2.22.0
# requests-file                     1.5.1
# requests-oauthlib                 1.3.0
# requests-toolbelt                 0.9.1
# requests-unixsocket               0.2.0
# retrying                          1.3.4
# rsa                               4.7.2
# scikit-image                      0.19.3
# scikit-learn                      1.0.1
# scipy                             1.7.3
# seaborn                           0.12.2
# segmentation-models               1.0.1
# Send2Trash                        1.8.0
# sentence-transformers             2.2.2
# sentencepiece                     0.1.97
# setuptools                        58.5.2
# six                               1.14.0
# sklearn                           0.0
# sniffio                           1.2.0
# sounddevice                       0.4.5
# soupsieve                         2.3.2.post1
# SQLAlchemy                        1.4.46
# sqlparse                          0.4.3
# sympy                             1.11.1
# tenacity                          8.0.1
# tensorboard                       2.11.0
# tensorboard-data-server           0.6.1
# tensorboard-plugin-wit            1.8.0
# tensorflow                        2.11.0
# tensorflow-estimator              2.11.0
# tensorflow-hub                    0.12.0
# tensorflow-io-gcs-filesystem      0.29.0
# tensorflow-text                   2.11.0
# termcolor                         1.1.0
# terminado                         0.12.1
# testpath                          0.5.0
# texttable                         1.6.7
# textwrap3                         0.9.2
# tflite-support                    0.4.3
# threadpoolctl                     3.0.0
# tifffile                          2022.10.10
# tokenizers                        0.13.2
# toml                              0.10.2
# torch                             1.9.1+cu111
# torchaudio                        0.9.1
# torchvision                       0.10.1+cu111
# tornado                           6.1
# tqdm                              4.62.3
# traitlets                         5.1.1
# traittypes                        0.2.1
# transformers                      4.25.1
# typing-extensions                 3.10.0.2
# umap-learn                        0.5.3
# urllib3                           1.25.8
# venn                              0.1.3
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.2.1
# websockets                        10.4
# Werkzeug                          2.2.3
# wheel                             0.34.2
# widgetsnbextension                3.5.2
# wrapt                             1.13.3
# wsproto                           1.2.0
# xlrd                              1.2.0
# yarl                              1.8.2
# zeep                              4.1.0
# zipp                              3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
app = Flask(__name__)
Swagger(app)


@app.route('/predict', methods=["POST"]) # get request from webpage and predict
def predict():
    # Define Swagger interface and Input 
    """NameMapping Algorithm
    
   Basic Service for Mapping of Manufacturer Names without any paramter options.
   Results with "0" represents possible new names.In this case manual correction is necessary.
   We used the best and evaluated model for this service !
   
   Please type the company name
    ---
    parameters:
      - name      : company_name 
        in        : query
        type      : string
        required  : true
    responses:
        8081:
            description: The output    
    """   
    
    input_request                     = request.args.get("company_name") # 
    
    result = jsonify('Es funktioniert ! Dein Input {}'.format(input_request ))
 
    ### ----------------------------------- in case of no parameters ------------------------

    return result

if __name__ == '__main__':
   app.run(host = '0.0.0.0', port=8081)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8081
#  * Running on http://172.17.0.2:8081
# Press CTRL+C to quit
# 192.168.124.86 - - [07/Mar/2023 15:45:11] "GET /apidocs/ HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:12] "GET /flasgger_static/lib/jquery.min.js HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:12] "GET /flasgger_static/swagger-ui-bundle.js HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:12] "GET /flasgger_static/swagger-ui-standalone-preset.js HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:12] "GET /flasgger_static/swagger-ui.css HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:13] "GET /flasgger_static/favicon-32x32.png HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:13] "GET /apispec_1.json HTTP/1.1" 200 -
# 192.168.124.86 - - [07/Mar/2023 15:45:18] "POST /predict?company_name=koto HTTP/1.1" 200 -

# %%
from flask import Flask
import os

app = Flask(__name__)

@app.route('/')
def hello():
    return "Hello World!"

if __name__ == '__main__':
    port = os.environ.get('FLASK_PORT') or 8080
    port = int(port)
    print(port)

    app.run(port=port,host='0.0.0.0')
# Out:
# 8080
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://172.17.0.2:8080
# Press CTRL+C to quit

# %%
from flask import Flask, request,render_template,jsonify
import flasgger
from flasgger import Swagger


app = Flask(__name__)
Swagger(app)
port = os.environ.get('FLASK_PORT') or 8080
port = int(port)
print(port)


@app.route('/predict', methods=["POST"]) # get request from webpage and predict
def predict():
    # Define Swagger interface and Input 
    """NameMapping Algorithm
    
   Basic Service for Mapping of Manufacturer Names without any paramter options.
   Results with "0" represents possible new names.In this case manual correction is necessary.
   We used the best and evaluated model for this service !
   
   Please type the company name
    ---
    parameters:
      - name      : company_name 
        in        : query
        type      : string
        required  : true
    responses:
        8081:
            description: The output    
    """   
    
    input_request                     = request.args.get("company_name") # 
    
    result = jsonify('Es funktioniert ! Dein Input {}'.format(input_request ))
 
    ### ----------------------------------- in case of no parameters ------------------------

    return result

if __name__ == '__main__':
   app.run(port=port,host='0.0.0.0')
